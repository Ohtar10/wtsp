# %% [markdown]
# # Product Review Embeddings
# ## Author: Luis Eduardo Ferro Diez <a href="mailto:luis.ferro1@correo.icesi.edu.co">luis.ferro1@correo.icesi.edu.co</a>
#
# This notebook contains the exploratory analysis over the Amazon product review dataset which will serve as ground truth of the semantic representation of the product categories for which we want later to characterize the geographic zones.
#
# ### Resources
# * Dataset: http://jmcauley.ucsd.edu/data/amazon/
#
# We are going to use the product reviews (aggresively deduplicated data) and the metadata of the products to build the semantic space.

# %%
metadata_path = "/media/ohtar10/Adder-Storage/datasets/amazon_products/reviews/metadata.json.gz"

# %% [markdown]
# Using the reading instructions from the web page since the json objects are not strict and cause problems when reading from pandas.
#
# Also, since the file is significantly big to the point it can't fit into memory, we need a mechanism that can read it in chunks.

# %%
import pandas as pd
import gzip
import json
from itertools import islice

def read_file(path, lines=100):
    f = gzip.open(path, 'r')
    for l in islice(f, lines):
        #yield json.dumps(eval(l))
        yield eval(l)
        
def generate_head_df(path, lines=100):
    df = {}
    for k, v in enumerate(read_file(path, lines)):
        df[k] = v
    return pd.DataFrame.from_dict(df, orient='index')

# %%
metadata_df = generate_head_df(metadata_path, 10000)
metadata_df.head()
# Out:
#          asin                 salesRank  \
# 0  0001048791        {'Books': 6334800}
# 1  0000143561   {'Movies & TV': 376041}
# 2  0000037214     {'Clothing': 1233557}
# 3  0000032069                       NaN
# 4  0000031909  {'Toys & Games': 201847}
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/51MKP0T4...
# 1  http://g-ecx.images-amazon.com/images/G/01/x-s...
# 2  http://ecx.images-amazon.com/images/I/31mCncNu...
# 3  http://ecx.images-amazon.com/images/I/51EzU6qu...
# 4  http://ecx.images-amazon.com/images/I/41xBoP0F...
#
#                                           categories  \
# 0                                          [[Books]]
# 1                            [[Movies & TV, Movies]]
# 2  [[Clothing, Shoes & Jewelry, Girls], [Clothing...
# 3  [[Sports & Outdoors, Other Sports, Dance, Clot...
# 4         [[Sports & Outdoors, Other Sports, Dance]]
#
#                                                title  \
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1  Everyday Italian (with Giada de Laurentiis), V...
# 2  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...
# 3                     Adult Ballet Tutu Cheetah Pink
# 4                        Girls Ballet Tutu Neon Pink
#
#                                          description  price  \
# 0                                                NaN    NaN
# 1  3Pack DVD set - Italian Classics, Parties and ...  12.99
# 2                                                NaN   6.99
# 3                                                NaN   7.89
# 4  High quality 3 layer ballet tutu. 12 inches in...   7.00
#
#                                              related       brand
# 0                                                NaN         NaN
# 1  {'also_viewed': ['B0036FO6SI', 'B000KL8ODE', '...         NaN
# 2  {'also_viewed': ['B00JO8II76', 'B00DGN4R1Q', '...  Big Dreams
# 3  {'also_bought': ['0000032050', 'B00D0DJAEG', '...    BubuBibi
# 4  {'also_bought': ['B002BZX8Z6', 'B00JHONN1S', '...     Unknown

# %% [markdown]
# We are interested in `asin`, `categories`, `title` and `description` columns, let's also check if we have null values there.

# %%
columns = ['asin', 'categories', 'title', 'description']
metadata_df = metadata_df[columns]
metadata_df.isnull().sum()
# Out:
# asin              0
# categories        7
# title             6
# description    5326
# dtype: int64

# %% [markdown]
# It seems we have several null values in description, but we can cope with that as we have the reviews. However, it seems we have null categories, this won't serve us well for our purpose so let's get rid of them. We must take care of not getting rid of the records that lack description.

# %%
metadata_df = metadata_df[metadata_df.categories.notnull()]
metadata_df.head()
# Out:
#          asin                                         categories  \
# 0  0001048791                                          [[Books]]
# 1  0000143561                            [[Movies & TV, Movies]]
# 2  0000037214  [[Clothing, Shoes & Jewelry, Girls], [Clothing...
# 3  0000032069  [[Sports & Outdoors, Other Sports, Dance, Clot...
# 4  0000031909         [[Sports & Outdoors, Other Sports, Dance]]
#
#                                                title  \
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1  Everyday Italian (with Giada de Laurentiis), V...
# 2  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...
# 3                     Adult Ballet Tutu Cheetah Pink
# 4                        Girls Ballet Tutu Neon Pink
#
#                                          description
# 0                                                NaN
# 1  3Pack DVD set - Italian Classics, Parties and ...
# 2                                                NaN
# 3                                                NaN
# 4  High quality 3 layer ballet tutu. 12 inches in...

# %%
metadata_df.isnull().sum()
# Out:
# asin              0
# categories        0
# title             4
# description    5322
# dtype: int64

# %% [markdown]
# We observe we have matrices for categories, it would be better to faltten them for easier usage.

# %%
from itertools import chain

categories = list(chain.from_iterable(metadata_df.categories.values))
categories[:10]
# Out:
# [['Books'],
#  ['Movies & TV', 'Movies'],
#  ['Clothing, Shoes & Jewelry', 'Girls'],
#  ['Clothing, Shoes & Jewelry',
#   'Novelty, Costumes & More',
#   'Costumes & Accessories',
#   'More Accessories',
#   'Kids & Baby'],
#  ['Sports & Outdoors', 'Other Sports', 'Dance', 'Clothing', 'Girls', 'Skirts'],
#  ['Sports & Outdoors', 'Other Sports', 'Dance'],
#  ['Sports & Outdoors', 'Other Sports', 'Dance', 'Clothing', 'Girls', 'Skirts'],
#  ['Movies & TV', 'Movies'],
#  ['Books'],
#  ['Sports & Outdoors', 'Other Sports', 'Dance']]

# %% [markdown]
# And flatten them and obtain the unique ones

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

# Use set to eliminate duplicates
categories_flat = set(flatten(categories))
categories_flat
# Out:
# {'Active',
#  'Active Skirts',
#  'Alternative Rock',
#  'Books',
#  'Business & Office',
#  'CDs & Vinyl',
#  "Children's",
#  "Children's Music",
#  'Christian',
#  'Clothing',
#  'Clothing, Shoes & Jewelry',
#  'Costumes & Accessories',
#  'Dance',
#  'General Accessories',
#  'Girls',
#  'Gospel',
#  'Indie & Lo-Fi',
#  'Indie Rock',
#  'Instrument Accessories',
#  'Jigsaw Puzzles',
#  'Kids & Baby',
#  'Lamps & Shades',
#  'Lighting & Ceiling Fans',
#  'More Accessories',
#  'Movies',
#  'Movies & TV',
#  'Musical Instruments',
#  'Novelty, Costumes & More',
#  'Other Sports',
#  'Pop & Contemporary',
#  'Praise & Worship',
#  'Puzzles',
#  'Sheet Music Folders',
#  'Skirts',
#  'Software',
#  'Sports & Outdoors',
#  'TV',
#  'Table Lamps',
#  'Tools & Home Improvement',
#  'Toys & Games',
#  'Visualization & Presentation'}

# %% [markdown]
# Now let's extract the titles and descriptions for each category as separate fields (as arrays) so we can use them for later processing.

# %%
# Create a new field with a flattened version of the categories column for better computation
metadata_df['categories_flattened'] = metadata_df.categories.apply(lambda cat: list(chain.from_iterable(cat)))
metadata_df.head()
# Out:
#          asin                                         categories  \
# 0  0001048791                                          [[Books]]
# 1  0000143561                            [[Movies & TV, Movies]]
# 2  0000037214  [[Clothing, Shoes & Jewelry, Girls], [Clothing...
# 3  0000032069  [[Sports & Outdoors, Other Sports, Dance, Clot...
# 4  0000031909         [[Sports & Outdoors, Other Sports, Dance]]
#
#                                                title  \
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1  Everyday Italian (with Giada de Laurentiis), V...
# 2  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...
# 3                     Adult Ballet Tutu Cheetah Pink
# 4                        Girls Ballet Tutu Neon Pink
#
#                                          description  \
# 0                                                NaN
# 1  3Pack DVD set - Italian Classics, Parties and ...
# 2                                                NaN
# 3                                                NaN
# 4  High quality 3 layer ballet tutu. 12 inches in...
#
#                                 categories_flattened
# 0                                            [Books]
# 1                              [Movies & TV, Movies]
# 2  [Clothing, Shoes & Jewelry, Girls, Clothing, S...
# 3  [Sports & Outdoors, Other Sports, Dance, Cloth...
# 4           [Sports & Outdoors, Other Sports, Dance]

# %% [markdown]
# The above modification allow us to perform some searching via lambdas.

# %%
books = metadata_df.categories_flattened.apply(lambda cl: 'Books' in cl)
metadata_df[books]
# Out:
#             asin categories  \
# 0     0001048791  [[Books]]
# 7     0001048775  [[Books]]
# 9     0001048236  [[Books]]
# 10    0000401048  [[Books]]
# 11    0001019880  [[Books]]
# ...          ...        ...
# 9995  0030547784  [[Books]]
# 9996  0030542987  [[Books]]
# 9997  0030543843  [[Books]]
# 9998  0030500036  [[Books]]
# 9999  0030546265  [[Books]]
#
#                                                   title  \
# 0     The Crucible: Performed by Stuart Pankin, Jero...
# 7        Measure for Measure: Complete &amp; Unabridged
# 9                  The Sherlock Holmes Audio Collection
# 10    The rogue of publishers' row;: Confessions of ...
# 11            Classic Soul Winner's New Testament Bible
# ...                                                 ...
# 9995  Holt McDougal Library: Individual Leveled Read...
# 9996  Holt, Rinehart and Winston Algebra 1: Student ...
# 9997  Datasheets for LabBook - Holt Science and Tech...
# 9998                            Biology, Fourth Edition
# 9999                             Hatch with Connections
#
#                                             description categories_flattened
# 0                                                   NaN              [Books]
# 7     William Shakespeare is widely regarded as the ...              [Books]
# 9     &#34;One thing is certain, Sherlockians, put a...              [Books]
# 10                                                  NaN              [Books]
# 11                                                  NaN              [Books]
# ...                                                 ...                  ...
# 9995                                                NaN              [Books]
# 9996                                                NaN              [Books]
# 9997                                                NaN              [Books]
# 9998                                                NaN              [Books]
# 9999                                                NaN              [Books]
#
# [9927 rows x 5 columns]

# %% [markdown]
# Let's define a function to facilitate this:

# %%
def get_products(df:pd.DataFrame, category:str, field='categories_flattened')-> pd.DataFrame:
    cat_indexes = df[field].apply(lambda cl: category in cl)
    return df[cat_indexes]

# %%
get_products(metadata_df, 'Movies')
# Out:
#             asin                                         categories  \
# 1     0000143561                            [[Movies & TV, Movies]]
# 6     0000589012                            [[Movies & TV, Movies]]
# 28    0000695009                            [[Movies & TV, Movies]]
# 34    000107461X                            [[Movies & TV, Movies]]
# 36    0000143529                            [[Movies & TV, Movies]]
# 45    0000143502                            [[Movies & TV, Movies]]
# 65    0000143588                            [[Movies & TV, Movies]]
# 66    0001517791                            [[Movies & TV, Movies]]
# 73    0001527665                            [[Movies & TV, Movies]]
# 91    0001516035                            [[Movies & TV, Movies]]
# 99    0000791156                            [[Movies & TV, Movies]]
# 210   0001485423                            [[Movies & TV, Movies]]
# 238   0001526863                            [[Movies & TV, Movies]]
# 1045  0005004101                            [[Movies & TV, Movies]]
# 1052  0005019222                            [[Movies & TV, Movies]]
# 1070  0005097258                            [[Movies & TV, Movies]]
# 1072  000503860X                            [[Movies & TV, Movies]]
# 1083  0005114349                            [[Movies & TV, Movies]]
# 1087  0005055121                            [[Movies & TV, Movies]]
# 1088  0005123909  [[CDs & Vinyl, Children's Music], [Movies & TV...
# 1092  0005089549                            [[Movies & TV, Movies]]
# 1096  0005253500                            [[Movies & TV, Movies]]
# 1099  0005097231                            [[Movies & TV, Movies]]
# 1107  0005054885                            [[Movies & TV, Movies]]
# 1114  0005257859                            [[Movies & TV, Movies]]
# 1115  0005257832                            [[Movies & TV, Movies]]
# 1117  0005134188  [[CDs & Vinyl, Children's Music], [Movies & TV...
# 1118  0005019281                            [[Movies & TV, Movies]]
# 1133  0005165687                            [[Movies & TV, Movies]]
# 1139  0005253446                            [[Movies & TV, Movies]]
# 1145  000510372X                            [[Movies & TV, Movies]]
# 1154  0005419263                            [[Movies & TV, Movies]]
# 1155  0005200288                            [[Movies & TV, Movies]]
# 1169  0005452287                            [[Movies & TV, Movies]]
# 1183  0005041104                            [[Movies & TV, Movies]]
# 1184  0005257891                            [[Movies & TV, Movies]]
# 1257  000547700X                            [[Movies & TV, Movies]]
# 1325  0005059836                            [[Movies & TV, Movies]]
# 4595  0011528230                            [[Movies & TV, Movies]]
# 4678  0012175447                            [[Movies & TV, Movies]]
#
#                                                   title  \
# 1     Everyday Italian (with Giada de Laurentiis), V...
# 6     Why Don't They Just Quit? DVD Roundtable Discu...
# 28              Understanding Seizures and Epilepsy DVD
# 34                                Live in Houston [VHS]
# 36                    My Fair Pastry (Good Eats Vol. 9)
# 45                    Rise and Swine (Good Eats Vol. 7)
# 65    Barefoot Contessa (with Ina Garten), Entertain...
# 66                                Praise Aerobics [VHS]
# 73                                    Peace Child [VHS]
# 91                          Worship with Don Moen [VHS]
# 99    Spirit Led-Moving By Grace In The Holy Spirit'...
# 210   The Life of Sister Faustina: The Apostle of Di...
# 238   Steve Green: Hide 'em in Your Heart: 13 Bible ...
# 1045                         Witnesses of Jehovah [VHS]
# 1052                       Waltons the Homecoming [VHS]
# 1070   Holy Ground: Moments of Worship and Praise [VHS]
# 1072                               Chapter X Live [VHS]
# 1083                                 Christmas is [VHS]
# 1087                 50 Years of Thorns and Roses [VHS]
# 1088  Silly Songs: 18 Wholesome Fun Songs for Kids [...
# 1092                 Cathedral Quartet: A Reunion [VHS]
# 1096  The Donut Man: Jesus Shows Us God's Love with ...
# 1099                                     Jus Jake [VHS]
# 1107                    Passion According to Luke [VHS]
# 1114                     Passion for His Presence [VHS]
# 1115                             Fear of the Lord [VHS]
# 1117                                Toddler Tunes [VHS]
# 1118                  An American Christmas Carol [VHS]
# 1133                       Laugh Yo' Self 2 Life! [VHS]
# 1139                   Steps to Freedom in Christ [VHS]
# 1145  The Mastery of Mimodrame: An In-Depth Study of...
# 1154  Steve Green: Hide 'em in Your Heart Volume 2: ...
# 1155  Walk Where Jesus Walked: A Life-Changing Visit...
# 1169                               Rejoice Africa [VHS]
# 1183  Camp Harmony (Rob Evans The Donut Man with Dun...
# 1184  Breaking Intimidation: How to Overcome Fear an...
# 1257                  Come Fly with the McGruders [VHS]
# 1325         Homecoming Kids Camp Out with Poster [VHS]
# 4595      Humor in Recovery by Father Joseph Martin DVD
# 4678             DVD-Cedarmont Kids: Gospel Bible Songs
#
#                                             description  \
# 1     3Pack DVD set - Italian Classics, Parties and ...
# 6                                                   NaN
# 28                                                  NaN
# 34                                                  NaN
# 36    Disc 1: Flour Power (Scones; Shortcakes; South...
# 45    Rise and Swine (Good Eats Vol. 7) includes bon...
# 65    Barefoot Contessa Volume 2: On these three dis...
# 66    Praise Aerobics - A low-intensity/high-intesit...
# 73                                                  NaN
# 91                          Worship with Don Moen [VHS]
# 99    You can flow effortlessly and powerfully in th...
# 210   Award winning British film director J. Paddy N...
# 238   Songs:\nLet the Little Children Come (Matthew ...
# 1045                                                NaN
# 1052                                                NEW
# 1070       Bill & Gloria Gaither and Homecoming Friends
# 1072                                                NaN
# 1083  Benji and Waldo discover the real meaning of C...
# 1087  Rare VHS tape mint in factory clam shell case....
# 1088  18 Music Videos for Kids: Do Your Ears Hang Lo...
# 1092                                      Reunion [VHS]
# 1096                                                NaN
# 1099  Gaither Hall of Honor Series\nA tribute to Jak...
# 1107                                          VHS tape.
# 1114                                                NaN
# 1115                                                NaN
# 1117                                           VHS Tape
# 1118  In Depression-era New England, a miserly busin...
# 1133                                                NaN
# 1139                                                NaN
# 1145                                                NaN
# 1154  Songs:\n1. Encourage One Another (1 Thessaloni...
# 1155  Overview\n\nHave you always wanted to visit Is...
# 1169                                          VHS, 1993
# 1183                                                NaN
# 1184                                               book
# 1257                                                NaN
# 1325  Featuring:Homecoming KidsPublisher:Gaither Mus...
# 4595  An infallible sign of a return to sobriety is ...
# 4678  DVD-Cedarmont Kids: Gospel Bible Songs by Ceda...
#
#                                    categories_flattened
# 1                                 [Movies & TV, Movies]
# 6                                 [Movies & TV, Movies]
# 28                                [Movies & TV, Movies]
# 34                                [Movies & TV, Movies]
# 36                                [Movies & TV, Movies]
# 45                                [Movies & TV, Movies]
# 65                                [Movies & TV, Movies]
# 66                                [Movies & TV, Movies]
# 73                                [Movies & TV, Movies]
# 91                                [Movies & TV, Movies]
# 99                                [Movies & TV, Movies]
# 210                               [Movies & TV, Movies]
# 238                               [Movies & TV, Movies]
# 1045                              [Movies & TV, Movies]
# 1052                              [Movies & TV, Movies]
# 1070                              [Movies & TV, Movies]
# 1072                              [Movies & TV, Movies]
# 1083                              [Movies & TV, Movies]
# 1087                              [Movies & TV, Movies]
# 1088  [CDs & Vinyl, Children's Music, Movies & TV, M...
# 1092                              [Movies & TV, Movies]
# 1096                              [Movies & TV, Movies]
# 1099                              [Movies & TV, Movies]
# 1107                              [Movies & TV, Movies]
# 1114                              [Movies & TV, Movies]
# 1115                              [Movies & TV, Movies]
# 1117  [CDs & Vinyl, Children's Music, Movies & TV, M...
# 1118                              [Movies & TV, Movies]
# 1133                              [Movies & TV, Movies]
# 1139                              [Movies & TV, Movies]
# 1145                              [Movies & TV, Movies]
# 1154                              [Movies & TV, Movies]
# 1155                              [Movies & TV, Movies]
# 1169                              [Movies & TV, Movies]
# 1183                              [Movies & TV, Movies]
# 1184                              [Movies & TV, Movies]
# 1257                              [Movies & TV, Movies]
# 1325                              [Movies & TV, Movies]
# 4595                              [Movies & TV, Movies]
# 4678                              [Movies & TV, Movies]

# %% [markdown]
# ## Combine with product reviews
# Now that we are able to obtain all the metadata for a particular category, let's now obtain the reviews per category. For a more interesting analysis, we are interested only in categories with ten or more reviews.

# %%
product_reviews_path = "/media/ohtar10/Adder-Storage/datasets/amazon_products/reviews/aggressive_dedup.json.gz"

# %%
pr_df = generate_head_df(product_reviews_path, 1000)
pr_df.head()
# Out:
#               reviewerID        asin     reviewerName helpful  \
# 0  A00000262KYZUE4J55XGL  B003UYU16G   Steven N Elich  [0, 0]
# 1  A000008615DZQRRI946FO  B005FYPK9C        mj waldon  [0, 0]
# 2  A00000922W28P2OCH6JSE  B000VEBG9Y  Gabriel Merrill  [0, 0]
# 3  A00000922W28P2OCH6JSE  B001EJMS6K  Gabriel Merrill  [0, 0]
# 4  A00000922W28P2OCH6JSE  B003XJCNVO  Gabriel Merrill  [0, 0]
#
#                                           reviewText  overall  \
# 0  It is and does exactly what the description sa...      5.0
# 1  I was sketchy at first about these but once yo...      5.0
# 2  Very mobile product. Efficient. Easy to use; h...      3.0
# 3  Easy to use a mobile. If you're taller than 4f...      4.0
# 4  Love this feeder. Heavy duty & capacity. Best ...      4.0
#
#                                              summary  unixReviewTime  \
# 0                      Does what it's supposed to do      1353456000
# 1                                          great buy      1357603200
# 2           Great product but needs a varmint guard.      1395619200
# 3  Great inexpensive product. Mounts easily and t...      1395619200
# 4  Great feeder. Would recommend for use for thos...      1395619200
#
#     reviewTime
# 0  11 21, 2012
# 1   01 8, 2013
# 2  03 24, 2014
# 3  03 24, 2014
# 4  03 24, 2014

# %% [markdown]
# We are interested only in what it was said about the product so we will only use: `asin`, `reviewText` and `summary`.

# %%
pr_columns = ['asin', 'summary', 'reviewText']
pr_df = pr_df[pr_columns]
pr_df.head()
# Out:
#          asin                                            summary  \
# 0  B003UYU16G                      Does what it's supposed to do
# 1  B005FYPK9C                                          great buy
# 2  B000VEBG9Y           Great product but needs a varmint guard.
# 3  B001EJMS6K  Great inexpensive product. Mounts easily and t...
# 4  B003XJCNVO  Great feeder. Would recommend for use for thos...
#
#                                           reviewText
# 0  It is and does exactly what the description sa...
# 1  I was sketchy at first about these but once yo...
# 2  Very mobile product. Efficient. Easy to use; h...
# 3  Easy to use a mobile. If you're taller than 4f...
# 4  Love this feeder. Heavy duty & capacity. Best ...

# %%
reviews_df = metadata_df.join(pr_df.set_index('asin'), on='asin', how='inner')
reviews_df.head()
# Out:
#             asin categories  \
# 3607  000727405X  [[Books]]
# 4201  0007444117  [[Books]]
#
#                                                   title  \
# 3607  Cry Silent Tears: The heartbreaking survival s...
# 4201                          Allegiant (Divergent, #3)
#
#                                             description categories_flattened  \
# 3607  Now thirty four years old, Joe Peters survived...              [Books]
# 4201                                                NaN              [Books]
#
#                                           summary  \
# 3607                         We need to know this
# 4201  Allegiant a great ending to a great series.
#
#                                              reviewText
# 3607  It really does happen that children are abused...
# 4201  Great book. Veronica Roth is extremely talente...

# %% [markdown]
# #### Note:
# No idea what I was trying to do here....

# %%
from collections import defaultdict

categories_dict = defaultdict(dict)
for cat in categories_flat:
    cat_indexes = metadata_df.categories_flattened.apply(lambda clist: cat in clist)
    filtered = metadata_df[cat_indexes]
    categories_dict[cat] = {'titles': filtered.title.values, }

# %% [markdown]
# ### Read the whole set in chunks
# Now that we have the basic idea of how to pre-process the datasets, let's try to read the whole files in chunks.

# %%
def read_file_chunks(path, line_number, chunksize=1000):
    f = gzip.open(path, 'r')
    for index in range(0, line_number, chunksize):
        for l in islice(f, index, chunksize):
            yield json.dumps(eval(l))
            
def generate_df(path, chunksize=1000):
    df = {}
    for k, v in enumerate(read_file_chunks(path, lines)):
        df[k] = v
    return pd.DataFrame.from_dict(df, orient='index')

# %%
import gc
import gzip
from itertools import islice
import pandas as pd

def read_file(path, start=0, chunksize=1000):
    f = gzip.open(path, 'r')
    for l in islice(f, start, chunksize):
        yield eval(l)
        
def generate_df(path, fields, max_lines, chunksize=1000):
    df = {}
    for index in range(0, max_lines, chunksize):
        for k, v in enumerate(read_file(path, index, chunksize), start=index):
            obj = {key:value for key, value in v.items() if key in fields}
            df[k] = obj
            # release memory
            del v
        gc.collect()
    return pd.DataFrame.from_dict(df, orient='index')

# %%
# %%time
metadata_fields = ['asin', 'categories', 'title', 'description']
metadata_full = generate_df(metadata_path, metadata_fields, 9430088, 10000)
# Out:
# CPU times: user 7h 1min 51s, sys: 4min 51s, total: 7h 6min 42s
# Wall time: 7h 6min 43s

# %%
metadata_full.head()
# Out:
#          asin                                         categories  \
# 0  0001048791                                          [[Books]]
# 1  0000143561                            [[Movies & TV, Movies]]
# 2  0000037214  [[Clothing, Shoes & Jewelry, Girls], [Clothing...
# 3  0000032069  [[Sports & Outdoors, Other Sports, Dance, Clot...
# 4  0000031909         [[Sports & Outdoors, Other Sports, Dance]]
#
#                                                title  \
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1  Everyday Italian (with Giada de Laurentiis), V...
# 2  Purple Sequin Tiny Dancer Tutu Ballet Dance Fa...
# 3                     Adult Ballet Tutu Cheetah Pink
# 4                        Girls Ballet Tutu Neon Pink
#
#                                          description
# 0                                                NaN
# 1  3Pack DVD set - Italian Classics, Parties and ...
# 2                                                NaN
# 3                                                NaN
# 4  High quality 3 layer ballet tutu. 12 inches in...

# %%
metadata_full.count()
# Out:
# asin           10000
# categories      9993
# title           9994
# description     4674
# dtype: int64

# %% [markdown]
# ### Warning!!!!
# Do not run these lines too often, these are only for counting the lines in the files as are needed for reading the file in chunks.

# %%
def count_lines(path:str)->int:
    with gzip.open(path, 'r') as file:
        return sum(1 for line in file)

# %%
# %%time
metadata_lines = count_lines(metadata_path)
# Out:
# CPU times: user 55.1 s, sys: 620 ms, total: 55.8 s
# Wall time: 55.8 s

# %%
# %%time
product_review_lines = count_lines(product_reviews_path)
# Out:
# CPU times: user 5min 28s, sys: 5.66 s, total: 5min 33s
# Wall time: 5min 33s

# %%
# For reference
print(f"Metadata lines {metadata_lines}")
print(f"Product review lines {product_review_lines}")
# Out:
# Metadata lines 9430088
# Product review lines 82456877

# %% [markdown]
# Metadata lines `9430088` Product review lines `82456877`
